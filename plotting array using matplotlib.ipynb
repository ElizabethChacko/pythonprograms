# %%
#plotting of real arrays using matplotlib
import matplotlib.pyplot as plt
from numpy import linspace,sin,pi,cos
x=linspace(0,2*pi,20)
plt.plot(x,sin(x),color='b')
plt.stem(x,cos(x),linefmt='g',markerfmt='r')
plt.show()
